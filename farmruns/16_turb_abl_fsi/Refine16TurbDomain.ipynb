# %% [markdown]
# # Refine the 16 NREL5MW turbine domain

# %%
# Add any possible locations of amr-wind-frontend here
amrwindfedirs = ['/projects/wind_uq/lcheung/amrwind-frontend',
                 '/ccs/proj/cfd162/lcheung/amrwind-frontend/']
import sys, os, shutil
for x in amrwindfedirs: sys.path.insert(1, x)

# Load the libraries
import amrwind_frontend  as amrwind
import matplotlib.pyplot as plt
import numpy             as np
import math
import pandas as pd
import postproamrwindsample as ppsample
import time
import utm
import shutil
import yaml

# Also ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Make all plots inline 
# %matplotlib inline

# %%
# Start the AMR-Wind case
case = amrwind.MyApp.init_nogui()

# %%
rundir = '/lustre/orion/cfd162/proj-shared/lcheung/ALCC_Frontier_WindFarm/windfarm/test/exawind-cases/16_turb_abl_fsi/run_refinedomain'
originalinput = 'nrel5mw_amr.inp'
outputfile    = 'nrel5mw_amr_refined.inp'

# %%
# Load the starting point
# This assumes that rundir was already set up with setup.sh (see https://github.com/Exawind/exawind-cases/blob/main/16_turb_abl_fsi/setup.sh)
os.chdir(rundir)
case.loadAMRWindInput(originalinput)
# Out:
# CANNOT update: ABLMeanBoussinesq use forcechange=True in setval()
# OrderedDict([('time.plot_start', '30000'),
#              ('BoussinesqBuoyancy.read_temperature_profile', 'true'),
#              ('BoussinesqBuoyancy.tprofile_filename',
#               '/lustre/orion/proj-shared/cfd162/shared/avg_theta.dat'),
#              ('CoriolisForcing.turn_off_vertical_force', 'True'),
#              ('ABL.inflow_outflow_mode', 'true'),
#              ('ABL.wf_velocity', '6.093275678667113 3.659473797517521'),
#              ('ABL.wf_vmag', '7.12794309269604'),
#              ('ABL.wf_theta', '300.2026467204779'),
#              ('ABL.enable_hybrid_rl_mode', 'true'),
#              ('amr.max_grid_size', '128'),
#              ('amr.blocking_factor', '32'),
#              ('nodal_proj.max_coarsening_level', '0'),
#              ('nodal_proj.num_pre_smooth', '10'),
#              ('nodal_proj.num_post_smooth', '10'),
#              ('nodal_proj.bottom_rtol', '1.0e-9'),
#              ('nodal_proj.bottom_atol', '1.0e-12'),
#              ('mac_proj.verbose', '0'),
#              ('mac_proj.max_coarsening_level', '0'),
#              ('mac_proj.do_nsolve', 'true'),
#              ('mac_proj.bottom_verbose', '0'),
#              ('mac_proj.bottom_rtol', '1.0e-11'),
#              ('mac_proj.bottom_atol', '1.0e-12'),
#              ('mac_proj.num_pre_smooth', '10'),
#              ('mac_proj.num_post_smooth', '10'),
#              ('diffusion.verbose', '0'),
#              ('diffusion.do_agglomeration', 'false'),
#              ('diffusion.do_nsolve', 'true'),
#              ('velocity_diffusion.verbose', '0'),
#              ('velocity_diffusion.use_tensor_operator', 'false'),
#              ('velocity_diffusion.use_segregated_operator', 'true'),
#              ('velocity_diffusion.do_nsolve', 'true'),
#              ('temperature_diffusion.verbose', '0'),
#              ('temperature_diffusion.do_nsolve', 'true'),
#              ('amrex.abort_on_out_of_gpu_memory', '1'),
#              ('amrex.the_arena_is_managed', '0'),
#              ('amrex.hypre_spgemm_use_vendor', '1'),
#              ('amrex.hypre_spmv_use_vendor', '0'),
#              ('amrex.hypre_sptrans_use_vendor', '0'),
#              ('amrex.hypre_umpire_device_pool_mbs', '4096'),
#              ('hypre.bamg_verbose', '0'),
#              ('hypre.verbose', '0'),
#              ('hypre.recompute_preconditioner', '0'),
#              ('hypre.hypre_solver', 'GMRES'),
#              ('hypre.hypre_preconditioner', 'BoomerAMG'),
#              ('hypre.num_krylov', '40'),
#              ('hypre.max_iterations', '40'),
#              ('hypre.rtol', '1.e-5'),
#              ('hypre.atol', '1.e-8'),
#              ('hypre.bamg_coarsen_type', '8'),
#              ('hypre.bamg_interp_type', '6'),
#              ('hypre.bamg_relax_type', '11'),
#              ('hypre.bamg_num_sweeps', '2'),
#              ('hypre.bamg_cycle_type', '1'),
#              ('hypre.bamg_relax_order', '0'),
#              ('hypre.bamg_trunc_factor', '0.45'),
#              ('hypre.bamg_strong_threshold', '0.3'),
#              ('hypre.bamg_min_coarse_size', '1'),
#              ('hypre.bamg_max_coarse_size', '100'),
#              ('hypre.bamg_agg_num_levels', '0'),
#              ('hypre.bamg_agg_interp_type', '7'),
#              ('hypre.bamg_agg_pmax_elmts', '3'),
#              ('hypre.bamg_pmax_elmts', '3'),
#              ('hypre.bamg_keep_transpose', '1'),
#              ('hypre.write_matrix_files', '0'),
#              ('hypre.bamg_smooth_type', '5'),
#              ('hypre.bamg_smooth_num_sweeps', '1'),
#              ('hypre.bamg_smooth_num_levels', '0'),
#              ('hypre.bamg_ilu_type', '0'),
#              ('hypre.bamg_ilu_level', '0'),
#              ('hypre.bamg_ilu_max_iter', '1'),
#              ('hypre.bamg_ilu_reordering_type', '0'),
#              ('hypre.bamg_ilu_tri_solve', '0'),
#              ('hypre.bamg_ilu_lower_jacobi_iters', '3'),
#              ('hypre.bamg_ilu_upper_jacobi_iters', '3')])

# %%
# Load the turbine locations
yamlfile = 'inp.yaml'
with open(yamlfile, 'r') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)

Nturbs=data['n_turbines_glob']

# %%
turbbase_xy = []
for i in range(Nturbs):
    turbbase_xy.append(data['turbine_info']['turb'+repr(i)]['turbine_base_pos'])

# %%
turbinetype = case.get_default_turbinetypedict()

turbinetype['turbinetype_name'] = 'NREL5MW_junk'
turbinetype['Actuator_type']    = 'UniformCtDisk'
turbinetype['Actuator_rotor_diameter']     = 126.0
turbinetype['Actuator_hub_height']         = 90.0
turbinetype['Actuator_epsilon']            = [2.5]
turbinetype['Actuator_output_frequency']   = 1
turbinetype['Actuator_diameters_to_sample']= 5.0 
turbinetype['Actuator_num_points_r']       = 20
turbinetype['Actuator_num_points_t']       = 3
turbinetype['Actuator_thrust_coeff']       = 0.2
case.add_populatefromdict('listboxturbinetype', turbinetype)

# %%
# Build the CSV input file of turbine layouts for amrwind-frontend

options=""

turbinescsv="""
# CSV file should have columns with
# name, x, y, type, yaw, hubheight, options
"""
rowformat="turb%i, %f, %f, NREL5MW_junk, 240.0, ,%s\n"
for iturb, xy in enumerate(turbbase_xy):
    turboptions  = options
    # uncomment this line for AWC
    #if iturb < 3:   turboptions += AWCoptions
    turbinescsv += rowformat%(iturb, xy[0], xy[1], turboptions)
case.setAMRWindInput('turbines_csvtextbox',  turbinescsv)
#print(turbinescsv)

# %%
case.setAMRWindInput('turbines_deleteprev', True)
case.setAMRWindInput('turbines_createnewdomain', False)

case.turbines_createAllTurbines()

# Print out existing list of turbines, just to confirm that the turbines got made
print(case.listboxpopupwindict['listboxactuator'].getitemlist())
# Out:
# ['turb0', 'turb1', 'turb2', 'turb3', 'turb4', 'turb5', 'turb6', 'turb7', 'turb8', 'turb9', 'turb10', 'turb11', 'turb12', 'turb13', 'turb14', 'turb15']

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = [] #['p_hub']
case.plotDomain(ax=ax)

# %%
case.estimateMeshSize()
# Out:
#  box 0 level 1: 42336000 cells
#  box 0 level 2: 338688000 cells
#  box 0 level 3: 2709504000 cells
#  box 0 level 4: 21676032000 cells
# ESTIMATED MESH SIZE
#    Level       Ncells                      Cell Size
#        0     50331648             10.0 x 10.0 x 10.0
#        1     42336000                5.0 x 5.0 x 5.0
#        2    338688000                2.5 x 2.5 x 2.5
#        3   2709504000             1.25 x 1.25 x 1.25
#        4  21676032000          0.625 x 0.625 x 0.625
#   TOTAL:  24816891648

# %%
## Add refinement zones
refinementcsv="""
# CSV file should have columns with
# level, upstream, downstream, lateral, below, above, options
level, upstream, downstream, lateral, below, above, options
0,     2160,     2160,       2160,    90,   200,   center:specified units:meter orientation:x centerx:2560 centery:2560 centerz:90 name:level1
1,     1600,     1600,       1600,    90,   200,   center:specified units:meter orientation:x centerx:2000 centery:2000 centerz:90 name:level2
2,     1.25,     2.0,        1.25,  0.75,   1.0, 
3,     0.75,     0.75,       1.00,  0.75,   0.75, 
"""
case.setAMRWindInput('refine_csvtextbox', refinementcsv)
case.setAMRWindInput('refine_deleteprev', True)
case.refine_createAllZones()

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = [] #['p_hub']
case.plotDomain(ax=ax)

# %%
case.estimateMeshSize()
# Out:
# Refinement level1: level 1: 43296768 cells
# Refinement level2: level 2: 190054400 cells
# Refinement turb0_level_2_zone: level 3: 14562737 cells
# Refinement turb1_level_2_zone: level 3: 14562737 cells
# Refinement turb2_level_2_zone: level 3: 14562737 cells
# Refinement turb3_level_2_zone: level 3: 14562737 cells
# Refinement turb4_level_2_zone: level 3: 14562737 cells
# Refinement turb5_level_2_zone: level 3: 14562737 cells
# Refinement turb6_level_2_zone: level 3: 14562737 cells
# Refinement turb7_level_2_zone: level 3: 14562737 cells
# Refinement turb8_level_2_zone: level 3: 14562737 cells
# Refinement turb9_level_2_zone: level 3: 14562737 cells
# Refinement turb10_level_2_zone: level 3: 14562737 cells
# Refinement turb11_level_2_zone: level 3: 14562737 cells
# Refinement turb12_level_2_zone: level 3: 14562737 cells
# Refinement turb13_level_2_zone: level 3: 14562737 cells
# Refinement turb14_level_2_zone: level 3: 14562737 cells
# Refinement turb15_level_2_zone: level 3: 14562737 cells
# Refinement turb0_level_3_zone: level 4: 36870930 cells
# Refinement turb1_level_3_zone: level 4: 36870930 cells
# Refinement turb2_level_3_zone: level 4: 36870930 cells
# Refinement turb3_level_3_zone: level 4: 36870930 cells
# Refinement turb4_level_3_zone: level 4: 36870930 cells
# Refinement turb5_level_3_zone: level 4: 36870930 cells
# Refinement turb6_level_3_zone: level 4: 36870930 cells
# Refinement turb7_level_3_zone: level 4: 36870930 cells
# Refinement turb8_level_3_zone: level 4: 36870930 cells
# Refinement turb9_level_3_zone: level 4: 36870930 cells
# Refinement turb10_level_3_zone: level 4: 36870930 cells
# Refinement turb11_level_3_zone: level 4: 36870930 cells
# Refinement turb12_level_3_zone: level 4: 36870930 cells
# Refinement turb13_level_3_zone: level 4: 36870930 cells
# Refinement turb14_level_3_zone: level 4: 36870930 cells
# Refinement turb15_level_3_zone: level 4: 36870930 cells
# ESTIMATED MESH SIZE
#    Level       Ncells                      Cell Size
#        0     50331648             10.0 x 10.0 x 10.0
#        1     43296768                5.0 x 5.0 x 5.0
#        2    190054400                2.5 x 2.5 x 2.5
#        3    233003792             1.25 x 1.25 x 1.25
#        4    589934880          0.625 x 0.625 x 0.625
#   TOTAL:   1106621488

# %% [markdown]
# ## Add some sampling planes

# %%
outputoptions="outputvars:velocity;tke;temperature outputfreq:25"
samplingcsv="""
# CSV file should have columns withturbinescsv=
# name, type, upstream, downstream, lateral, below, above, n1, n2, options
name, type, upstream, downstream, lateral, below, above, n1, n2, options
#cl1, centerline, 1,  0, none, none,  none,  11, 11, none
#rp1, rotorplane, 2,  0, none, none,  none,  11, 11, none
#sw1, streamwise, 2,  1, 1, 0.5,  0.5,  11, 11, usedx:0.25 noffsets:1
turbsw,    streamwise, 4,        4,         2,      0.7,    1.5,     11, 11, usedx:0.05 outputto:turbsw_ orientation:nacdir {outputoptions} noffsets:0
turbhh,    hubheight,  4,        4,         2,       0,     1.5,     11, 11, usedx:0.05 outputto:turbhh_ orientation:nacdir {outputoptions} noffsets:0
turbdomain,hubheight,  8,        8,         2,       0,     126,     11, 11, units:meter usedx:16 outputto:turbdomain_ orientation:nacdir center:farm wholedomain:1  {outputoptions} noffsets:1
""".format(outputoptions=outputoptions)

case.setAMRWindInput('sampling_csvtextbox', samplingcsv)
case.setAMRWindInput('sampling_deleteprev', True)

# %%
case.sampling_createAllProbes(verbose=False)
# Print out existing list of turbines
print(case.listboxpopupwindict['listboxsampling'].getitemlist())
# Out:
# ['turb0_turbsw', 'turb1_turbsw', 'turb2_turbsw', 'turb3_turbsw', 'turb4_turbsw', 'turb5_turbsw', 'turb6_turbsw', 'turb7_turbsw', 'turb8_turbsw', 'turb9_turbsw', 'turb10_turbsw', 'turb11_turbsw', 'turb12_turbsw', 'turb13_turbsw', 'turb14_turbsw', 'turb15_turbsw', 'turb0_turbhh', 'turb1_turbhh', 'turb2_turbhh', 'turb3_turbhh', 'turb4_turbhh', 'turb5_turbhh', 'turb6_turbhh', 'turb7_turbhh', 'turb8_turbhh', 'turb9_turbhh', 'turb10_turbhh', 'turb11_turbhh', 'turb12_turbhh', 'turb13_turbhh', 'turb14_turbhh', 'turb15_turbhh', 'Farm_turbdomain']

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] #case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = case.listboxpopupwindict['listboxsampling'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes_style'] = "{'markersize':.1, 'marker':'.', 'linestyle':'None', 'alpha':0.1}"
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend']= "{'title':'Sampling probes', 'fontsize':6, 'loc':'upper left', 'markerscale':10}"
case.plotDomain(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] #case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = case.listboxpopupwindict['listboxsampling'].getitemlist()
case.popup_storteddata['plotdomain']['plot_sampleprobes_style'] = "{'markersize':.1, 'marker':'.', 'linestyle':'None'}"
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XZ'
case.plotDomain(ax=ax)

# %%
## Create a version without turbines
case.removeturbines()
inputfile=case.writeAMRWindInput(outputfile)
print(inputfile)
# Out:
# # --- Simulation time control parameters ---
# time.stop_time                           = -1.0                # Max (simulated) time to evolve [s]
# time.max_step                            = -1
# time.fixed_dt                            = 0.003443526170799   # Fixed timestep size (in seconds). If negative, then time.cfl is used
# time.checkpoint_interval                 = -1
# incflo.physics                           = ABL                 # List of physics models to include in simulation.
# incflo.verbose                           = 0
# io.check_file                            = chk
# io.restart_file                          = /lustre/orion/proj-shared/cfd162/shared/chk30000
# incflo.use_godunov                       = true
# incflo.godunov_type                      = weno_z
# turbulence.model                         = OneEqKsgsM84
# TKE.source_terms                         = KsgsM84Src
# nodal_proj.mg_rtol                       = 1e-06
# nodal_proj.mg_atol                       = 1e-10
# mac_proj.mg_rtol                         = 1e-06
# mac_proj.mg_atol                         = 1e-10
# nodal_proj.verbose                       = 0
# incflo.gravity                           = 0.0 0.0 -9.81       # Gravitational acceleration vector (x,y,z) [m/s^2]
# incflo.density                           = 1.0                 # Fluid density [kg/m^3]
# transport.viscosity                      = 0.0                 # Fluid dynamic viscosity [kg/m-s]
# transport.laminar_prandtl                = 0.7                 # Laminar prandtl number
# transport.turbulent_prandtl              = 0.3333              # Turbulent prandtl number
#
# # --- Geometry and Mesh ---
# geometry.prob_lo                         = 0.0 0.0 0.0
# geometry.prob_hi                         = 5120.0 5120.0 1920.0
# amr.n_cell                               = 512 512 192         # Number of cells in x, y, and z directions
# amr.max_level                            = 4
# geometry.is_periodic                     = 0 0 0
# xlo.type                                 = mass_inflow
# xlo.density                              = 1.0
# xlo.temperature                          = 0.0
# xlo.tke                                  = 0.0
# xhi.type                                 = pressure_outflow
# ylo.type                                 = mass_inflow
# ylo.density                              = 1.0
# ylo.temperature                          = 0.0
# ylo.tke                                  = 0.0
# yhi.type                                 = pressure_outflow
# zlo.type                                 = wall_model
# zlo.temperature_type                     = wall_model
# zlo.tke_type                             = zero_gradient
# zhi.type                                 = slip_wall
# zhi.temperature_type                     = fixed_gradient
# zhi.temperature                          = 0.003
#
# # --- ABL parameters ---
# ICNS.source_terms                        = BoussinesqBuoyancy CoriolisForcing BodyForce ABLMeanBoussinesq
# ABL.bndry_io_mode                        = 1
# ABL.bndry_file                           = /lustre/orion/proj-shared/cfd162/shared/bndry_file
# ABL.bndry_planes                         = xlo ylo
# ABL.bndry_output_start_time              = 15000.0
# ABL.bndry_var_names                      = velocity temperature tke
# ABL.bndry_output_format                  = native
# incflo.velocity                          = 9.8726896031426 5.7 0.0
# ABLForcing.abl_forcing_height            = 0.0
# ABL.kappa                                = 0.41
# ABL.normal_direction                     = 2
# ABL.surface_roughness_z0                 = 0.01
# ABL.reference_temperature                = 300.0
# ABL.surface_temp_rate                    = 0.0
# ABL.surface_temp_flux                    = 0.005               # Surface temperature flux [K-m/s]
# ABL.log_law_height                       = 5.0
# ABL.wall_shear_stress_type               = local
# CoriolisForcing.latitude                 = 40.0
# CoriolisForcing.rotational_time_period   = 86400.0
# CoriolisForcing.north_vector             = 0.0 1.0 0.0
# CoriolisForcing.east_vector              = 1.0 0.0 0.0
# BoussinesqBuoyancy.reference_temperature = 300.0
# BodyForce.magnitude                      = -0.000349710865169856 0.0011134941091590048 0.0
# ABL.temperature_heights                  = 0.0 750.0 850.0 2000.0
# ABL.temperature_values                   = 300.0 300.0 308.0 311.45
# time.plot_interval                       = -1
# io.plot_file                             = plt
# io.KE_int                                = -1
#
# #---- tagging defs ----
# tagging.labels                           = level1 level2 turb0_level_2_zone turb1_level_2_zone turb2_level_2_zone turb3_level_2_zone turb4_level_2_zone turb5_level_2_zone turb6_level_2_zone turb7_level_2_zone turb8_level_2_zone turb9_level_2_zone turb10_level_2_zone turb11_level_2_zone turb12_level_2_zone turb13_level_2_zone turb14_level_2_zone turb15_level_2_zone turb0_level_3_zone turb1_level_3_zone turb2_level_3_zone turb3_level_3_zone turb4_level_3_zone turb5_level_3_zone turb6_level_3_zone turb7_level_3_zone turb8_level_3_zone turb9_level_3_zone turb10_level_3_zone turb11_level_3_zone turb12_level_3_zone turb13_level_3_zone turb14_level_3_zone turb15_level_3_zone
# tagging.level1.type                      = GeometryRefinement
# tagging.level1.shapes                    = level1
# tagging.level1.level                     = 0
# tagging.level1.level1.type               = box
# tagging.level1.level1.origin             = 400.0 400.0 0.0
# tagging.level1.level1.xaxis              = 4320.0 0.0 0.0
# tagging.level1.level1.yaxis              = 0.0 4320.0 0.0
# tagging.level1.level1.zaxis              = 0.0 0.0 290.0
# tagging.level2.type                      = GeometryRefinement
# tagging.level2.shapes                    = level2
# tagging.level2.level                     = 1
# tagging.level2.level2.type               = box
# tagging.level2.level2.origin             = 400.0 400.0 0.0
# tagging.level2.level2.xaxis              = 3200.0 0.0 0.0
# tagging.level2.level2.yaxis              = 0.0 3200.0 0.0
# tagging.level2.level2.zaxis              = 0.0 0.0 290.0
# tagging.turb0_level_2_zone.type          = GeometryRefinement
# tagging.turb0_level_2_zone.shapes        = turb0_level_2_zone
# tagging.turb0_level_2_zone.level         = 2
# tagging.turb0_level_2_zone.turb0_level_2_zone.type = box
# tagging.turb0_level_2_zone.turb0_level_2_zone.origin = 567.3509989039509 409.8509989039509 -4.5
# tagging.turb0_level_2_zone.turb0_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb0_level_2_zone.turb0_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb0_level_2_zone.turb0_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb1_level_2_zone.type          = GeometryRefinement
# tagging.turb1_level_2_zone.shapes        = turb1_level_2_zone
# tagging.turb1_level_2_zone.level         = 2
# tagging.turb1_level_2_zone.turb1_level_2_zone.type = box
# tagging.turb1_level_2_zone.turb1_level_2_zone.origin = 667.3509989039509 909.8509989039509 -4.5
# tagging.turb1_level_2_zone.turb1_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb1_level_2_zone.turb1_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb1_level_2_zone.turb1_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb2_level_2_zone.type          = GeometryRefinement
# tagging.turb2_level_2_zone.shapes        = turb2_level_2_zone
# tagging.turb2_level_2_zone.level         = 2
# tagging.turb2_level_2_zone.turb2_level_2_zone.type = box
# tagging.turb2_level_2_zone.turb2_level_2_zone.origin = 1067.3509989039508 509.8509989039509 -4.5
# tagging.turb2_level_2_zone.turb2_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb2_level_2_zone.turb2_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb2_level_2_zone.turb2_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb3_level_2_zone.type          = GeometryRefinement
# tagging.turb3_level_2_zone.shapes        = turb3_level_2_zone
# tagging.turb3_level_2_zone.level         = 2
# tagging.turb3_level_2_zone.turb3_level_2_zone.type = box
# tagging.turb3_level_2_zone.turb3_level_2_zone.origin = 767.3509989039509 1409.850998903951 -4.5
# tagging.turb3_level_2_zone.turb3_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb3_level_2_zone.turb3_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb3_level_2_zone.turb3_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb4_level_2_zone.type          = GeometryRefinement
# tagging.turb4_level_2_zone.shapes        = turb4_level_2_zone
# tagging.turb4_level_2_zone.level         = 2
# tagging.turb4_level_2_zone.turb4_level_2_zone.type = box
# tagging.turb4_level_2_zone.turb4_level_2_zone.origin = 1167.350998903951 1009.8509989039509 -4.5
# tagging.turb4_level_2_zone.turb4_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb4_level_2_zone.turb4_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb4_level_2_zone.turb4_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb5_level_2_zone.type          = GeometryRefinement
# tagging.turb5_level_2_zone.shapes        = turb5_level_2_zone
# tagging.turb5_level_2_zone.level         = 2
# tagging.turb5_level_2_zone.turb5_level_2_zone.type = box
# tagging.turb5_level_2_zone.turb5_level_2_zone.origin = 1567.350998903951 609.8509989039509 -4.5
# tagging.turb5_level_2_zone.turb5_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb5_level_2_zone.turb5_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb5_level_2_zone.turb5_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb6_level_2_zone.type          = GeometryRefinement
# tagging.turb6_level_2_zone.shapes        = turb6_level_2_zone
# tagging.turb6_level_2_zone.level         = 2
# tagging.turb6_level_2_zone.turb6_level_2_zone.type = box
# tagging.turb6_level_2_zone.turb6_level_2_zone.origin = 867.3509989039509 1909.850998903951 -4.5
# tagging.turb6_level_2_zone.turb6_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb6_level_2_zone.turb6_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb6_level_2_zone.turb6_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb7_level_2_zone.type          = GeometryRefinement
# tagging.turb7_level_2_zone.shapes        = turb7_level_2_zone
# tagging.turb7_level_2_zone.level         = 2
# tagging.turb7_level_2_zone.turb7_level_2_zone.type = box
# tagging.turb7_level_2_zone.turb7_level_2_zone.origin = 1267.350998903951 1509.850998903951 -4.5
# tagging.turb7_level_2_zone.turb7_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb7_level_2_zone.turb7_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb7_level_2_zone.turb7_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb8_level_2_zone.type          = GeometryRefinement
# tagging.turb8_level_2_zone.shapes        = turb8_level_2_zone
# tagging.turb8_level_2_zone.level         = 2
# tagging.turb8_level_2_zone.turb8_level_2_zone.type = box
# tagging.turb8_level_2_zone.turb8_level_2_zone.origin = 1667.350998903951 1109.850998903951 -4.5
# tagging.turb8_level_2_zone.turb8_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb8_level_2_zone.turb8_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb8_level_2_zone.turb8_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb9_level_2_zone.type          = GeometryRefinement
# tagging.turb9_level_2_zone.shapes        = turb9_level_2_zone
# tagging.turb9_level_2_zone.level         = 2
# tagging.turb9_level_2_zone.turb9_level_2_zone.type = box
# tagging.turb9_level_2_zone.turb9_level_2_zone.origin = 2067.3509989039508 709.8509989039509 -4.5
# tagging.turb9_level_2_zone.turb9_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb9_level_2_zone.turb9_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb9_level_2_zone.turb9_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb10_level_2_zone.type         = GeometryRefinement
# tagging.turb10_level_2_zone.shapes       = turb10_level_2_zone
# tagging.turb10_level_2_zone.level        = 2
# tagging.turb10_level_2_zone.turb10_level_2_zone.type = box
# tagging.turb10_level_2_zone.turb10_level_2_zone.origin = 1367.350998903951 2009.850998903951 -4.5
# tagging.turb10_level_2_zone.turb10_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb10_level_2_zone.turb10_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb10_level_2_zone.turb10_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb11_level_2_zone.type         = GeometryRefinement
# tagging.turb11_level_2_zone.shapes       = turb11_level_2_zone
# tagging.turb11_level_2_zone.level        = 2
# tagging.turb11_level_2_zone.turb11_level_2_zone.type = box
# tagging.turb11_level_2_zone.turb11_level_2_zone.origin = 1767.350998903951 1609.850998903951 -4.5
# tagging.turb11_level_2_zone.turb11_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb11_level_2_zone.turb11_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb11_level_2_zone.turb11_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb12_level_2_zone.type         = GeometryRefinement
# tagging.turb12_level_2_zone.shapes       = turb12_level_2_zone
# tagging.turb12_level_2_zone.level        = 2
# tagging.turb12_level_2_zone.turb12_level_2_zone.type = box
# tagging.turb12_level_2_zone.turb12_level_2_zone.origin = 2167.3509989039508 1209.850998903951 -4.5
# tagging.turb12_level_2_zone.turb12_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb12_level_2_zone.turb12_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb12_level_2_zone.turb12_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb13_level_2_zone.type         = GeometryRefinement
# tagging.turb13_level_2_zone.shapes       = turb13_level_2_zone
# tagging.turb13_level_2_zone.level        = 2
# tagging.turb13_level_2_zone.turb13_level_2_zone.type = box
# tagging.turb13_level_2_zone.turb13_level_2_zone.origin = 1867.350998903951 2109.8509989039508 -4.5
# tagging.turb13_level_2_zone.turb13_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb13_level_2_zone.turb13_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb13_level_2_zone.turb13_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb14_level_2_zone.type         = GeometryRefinement
# tagging.turb14_level_2_zone.shapes       = turb14_level_2_zone
# tagging.turb14_level_2_zone.level        = 2
# tagging.turb14_level_2_zone.turb14_level_2_zone.type = box
# tagging.turb14_level_2_zone.turb14_level_2_zone.origin = 2267.3509989039508 1709.850998903951 -4.5
# tagging.turb14_level_2_zone.turb14_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb14_level_2_zone.turb14_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb14_level_2_zone.turb14_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb15_level_2_zone.type         = GeometryRefinement
# tagging.turb15_level_2_zone.shapes       = turb15_level_2_zone
# tagging.turb15_level_2_zone.level        = 2
# tagging.turb15_level_2_zone.turb15_level_2_zone.type = box
# tagging.turb15_level_2_zone.turb15_level_2_zone.origin = 2367.3509989039508 2209.8509989039508 -4.5
# tagging.turb15_level_2_zone.turb15_level_2_zone.xaxis = 354.63740284972766 204.74999999999997 0.0
# tagging.turb15_level_2_zone.turb15_level_2_zone.yaxis = -157.49999999999997 272.7980021920982 -0.0
# tagging.turb15_level_2_zone.turb15_level_2_zone.zaxis = 0.0 0.0 220.5
# tagging.turb0_level_3_zone.type          = GeometryRefinement
# tagging.turb0_level_3_zone.shapes        = turb0_level_3_zone
# tagging.turb0_level_3_zone.level         = 3
# tagging.turb0_level_3_zone.turb0_level_3_zone.type = box
# tagging.turb0_level_3_zone.turb0_level_3_zone.origin = 606.1605993423706 468.6307991231607 -4.5
# tagging.turb0_level_3_zone.turb0_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb0_level_3_zone.turb0_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb0_level_3_zone.turb0_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb1_level_3_zone.type          = GeometryRefinement
# tagging.turb1_level_3_zone.shapes        = turb1_level_3_zone
# tagging.turb1_level_3_zone.level         = 3
# tagging.turb1_level_3_zone.turb1_level_3_zone.type = box
# tagging.turb1_level_3_zone.turb1_level_3_zone.origin = 706.1605993423706 968.6307991231607 -4.5
# tagging.turb1_level_3_zone.turb1_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb1_level_3_zone.turb1_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb1_level_3_zone.turb1_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb2_level_3_zone.type          = GeometryRefinement
# tagging.turb2_level_3_zone.shapes        = turb2_level_3_zone
# tagging.turb2_level_3_zone.level         = 3
# tagging.turb2_level_3_zone.turb2_level_3_zone.type = box
# tagging.turb2_level_3_zone.turb2_level_3_zone.origin = 1106.1605993423705 568.6307991231607 -4.5
# tagging.turb2_level_3_zone.turb2_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb2_level_3_zone.turb2_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb2_level_3_zone.turb2_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb3_level_3_zone.type          = GeometryRefinement
# tagging.turb3_level_3_zone.shapes        = turb3_level_3_zone
# tagging.turb3_level_3_zone.level         = 3
# tagging.turb3_level_3_zone.turb3_level_3_zone.type = box
# tagging.turb3_level_3_zone.turb3_level_3_zone.origin = 806.1605993423706 1468.6307991231606 -4.5
# tagging.turb3_level_3_zone.turb3_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb3_level_3_zone.turb3_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb3_level_3_zone.turb3_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb4_level_3_zone.type          = GeometryRefinement
# tagging.turb4_level_3_zone.shapes        = turb4_level_3_zone
# tagging.turb4_level_3_zone.level         = 3
# tagging.turb4_level_3_zone.turb4_level_3_zone.type = box
# tagging.turb4_level_3_zone.turb4_level_3_zone.origin = 1206.1605993423705 1068.6307991231606 -4.5
# tagging.turb4_level_3_zone.turb4_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb4_level_3_zone.turb4_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb4_level_3_zone.turb4_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb5_level_3_zone.type          = GeometryRefinement
# tagging.turb5_level_3_zone.shapes        = turb5_level_3_zone
# tagging.turb5_level_3_zone.level         = 3
# tagging.turb5_level_3_zone.turb5_level_3_zone.type = box
# tagging.turb5_level_3_zone.turb5_level_3_zone.origin = 1606.1605993423705 668.6307991231607 -4.5
# tagging.turb5_level_3_zone.turb5_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb5_level_3_zone.turb5_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb5_level_3_zone.turb5_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb6_level_3_zone.type          = GeometryRefinement
# tagging.turb6_level_3_zone.shapes        = turb6_level_3_zone
# tagging.turb6_level_3_zone.level         = 3
# tagging.turb6_level_3_zone.turb6_level_3_zone.type = box
# tagging.turb6_level_3_zone.turb6_level_3_zone.origin = 906.1605993423706 1968.6307991231606 -4.5
# tagging.turb6_level_3_zone.turb6_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb6_level_3_zone.turb6_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb6_level_3_zone.turb6_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb7_level_3_zone.type          = GeometryRefinement
# tagging.turb7_level_3_zone.shapes        = turb7_level_3_zone
# tagging.turb7_level_3_zone.level         = 3
# tagging.turb7_level_3_zone.turb7_level_3_zone.type = box
# tagging.turb7_level_3_zone.turb7_level_3_zone.origin = 1306.1605993423705 1568.6307991231606 -4.5
# tagging.turb7_level_3_zone.turb7_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb7_level_3_zone.turb7_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb7_level_3_zone.turb7_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb8_level_3_zone.type          = GeometryRefinement
# tagging.turb8_level_3_zone.shapes        = turb8_level_3_zone
# tagging.turb8_level_3_zone.level         = 3
# tagging.turb8_level_3_zone.turb8_level_3_zone.type = box
# tagging.turb8_level_3_zone.turb8_level_3_zone.origin = 1706.1605993423705 1168.6307991231606 -4.5
# tagging.turb8_level_3_zone.turb8_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb8_level_3_zone.turb8_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb8_level_3_zone.turb8_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb9_level_3_zone.type          = GeometryRefinement
# tagging.turb9_level_3_zone.shapes        = turb9_level_3_zone
# tagging.turb9_level_3_zone.level         = 3
# tagging.turb9_level_3_zone.turb9_level_3_zone.type = box
# tagging.turb9_level_3_zone.turb9_level_3_zone.origin = 2106.1605993423705 768.6307991231607 -4.5
# tagging.turb9_level_3_zone.turb9_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb9_level_3_zone.turb9_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb9_level_3_zone.turb9_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb10_level_3_zone.type         = GeometryRefinement
# tagging.turb10_level_3_zone.shapes       = turb10_level_3_zone
# tagging.turb10_level_3_zone.level        = 3
# tagging.turb10_level_3_zone.turb10_level_3_zone.type = box
# tagging.turb10_level_3_zone.turb10_level_3_zone.origin = 1406.1605993423705 2068.6307991231606 -4.5
# tagging.turb10_level_3_zone.turb10_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb10_level_3_zone.turb10_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb10_level_3_zone.turb10_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb11_level_3_zone.type         = GeometryRefinement
# tagging.turb11_level_3_zone.shapes       = turb11_level_3_zone
# tagging.turb11_level_3_zone.level        = 3
# tagging.turb11_level_3_zone.turb11_level_3_zone.type = box
# tagging.turb11_level_3_zone.turb11_level_3_zone.origin = 1806.1605993423705 1668.6307991231606 -4.5
# tagging.turb11_level_3_zone.turb11_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb11_level_3_zone.turb11_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb11_level_3_zone.turb11_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb12_level_3_zone.type         = GeometryRefinement
# tagging.turb12_level_3_zone.shapes       = turb12_level_3_zone
# tagging.turb12_level_3_zone.level        = 3
# tagging.turb12_level_3_zone.turb12_level_3_zone.type = box
# tagging.turb12_level_3_zone.turb12_level_3_zone.origin = 2206.1605993423705 1268.6307991231606 -4.5
# tagging.turb12_level_3_zone.turb12_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb12_level_3_zone.turb12_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb12_level_3_zone.turb12_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb13_level_3_zone.type         = GeometryRefinement
# tagging.turb13_level_3_zone.shapes       = turb13_level_3_zone
# tagging.turb13_level_3_zone.level        = 3
# tagging.turb13_level_3_zone.turb13_level_3_zone.type = box
# tagging.turb13_level_3_zone.turb13_level_3_zone.origin = 1906.1605993423705 2168.6307991231606 -4.5
# tagging.turb13_level_3_zone.turb13_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb13_level_3_zone.turb13_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb13_level_3_zone.turb13_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb14_level_3_zone.type         = GeometryRefinement
# tagging.turb14_level_3_zone.shapes       = turb14_level_3_zone
# tagging.turb14_level_3_zone.level        = 3
# tagging.turb14_level_3_zone.turb14_level_3_zone.type = box
# tagging.turb14_level_3_zone.turb14_level_3_zone.origin = 2306.1605993423705 1768.6307991231606 -4.5
# tagging.turb14_level_3_zone.turb14_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb14_level_3_zone.turb14_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb14_level_3_zone.turb14_level_3_zone.zaxis = 0.0 0.0 189.0
# tagging.turb15_level_3_zone.type         = GeometryRefinement
# tagging.turb15_level_3_zone.shapes       = turb15_level_3_zone
# tagging.turb15_level_3_zone.level        = 3
# tagging.turb15_level_3_zone.turb15_level_3_zone.type = box
# tagging.turb15_level_3_zone.turb15_level_3_zone.origin = 2406.1605993423705 2268.6307991231606 -4.5
# tagging.turb15_level_3_zone.turb15_level_3_zone.xaxis = 163.6788013152589 94.49999999999999 0.0
# tagging.turb15_level_3_zone.turb15_level_3_zone.yaxis = -125.99999999999999 218.23840175367854 -0.0
# tagging.turb15_level_3_zone.turb15_level_3_zone.zaxis = 0.0 0.0 189.0
#
# #---- postprocessing defs ----
# incflo.post_processing                   = turbsw_ turbhh_ turbdomain_
# turbsw_.type                             = Sampling
# turbsw_.output_frequency                 = 25
# turbsw_.fields                           = velocity temperature tke
# turbhh_.type                             = Sampling
# turbhh_.output_frequency                 = 25
# turbhh_.fields                           = velocity temperature tke
# turbdomain_.type                         = Sampling
# turbdomain_.output_frequency             = 25
# turbdomain_.fields                       = velocity temperature tke
#
# #---- sample defs ----
# turbsw_.labels                           = turb0_turbsw turb1_turbsw turb2_turbsw turb3_turbsw turb4_turbsw turb5_turbsw turb6_turbsw turb7_turbsw turb8_turbsw turb9_turbsw turb10_turbsw turb11_turbsw turb12_turbsw turb13_turbsw turb14_turbsw turb15_turbsw
# turbhh_.labels                           = turb0_turbhh turb1_turbhh turb2_turbhh turb3_turbhh turb4_turbhh turb5_turbhh turb6_turbhh turb7_turbhh turb8_turbhh turb9_turbhh turb10_turbhh turb11_turbhh turb12_turbhh turb13_turbhh turb14_turbhh turb15_turbhh
# turbdomain_.labels                       = Farm_turbdomain
# turbsw_.turb0_turbsw.type                = PlaneSampler
# turbsw_.turb0_turbsw.num_points          = 161 45
# turbsw_.turb0_turbsw.origin              = 188.5231964926429 373.0 1.8000000000000114
# turbsw_.turb0_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb0_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb0_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb1_turbsw.type                = PlaneSampler
# turbsw_.turb1_turbsw.num_points          = 161 45
# turbsw_.turb1_turbsw.origin              = 288.5231964926429 873.0 1.8000000000000114
# turbsw_.turb1_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb1_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb1_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb2_turbsw.type                = PlaneSampler
# turbsw_.turb2_turbsw.num_points          = 161 45
# turbsw_.turb2_turbsw.origin              = 688.5231964926429 473.0 1.8000000000000114
# turbsw_.turb2_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb2_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb2_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb3_turbsw.type                = PlaneSampler
# turbsw_.turb3_turbsw.num_points          = 161 45
# turbsw_.turb3_turbsw.origin              = 388.5231964926429 1373.0 1.8000000000000114
# turbsw_.turb3_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb3_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb3_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb4_turbsw.type                = PlaneSampler
# turbsw_.turb4_turbsw.num_points          = 161 45
# turbsw_.turb4_turbsw.origin              = 788.5231964926429 973.0 1.8000000000000114
# turbsw_.turb4_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb4_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb4_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb5_turbsw.type                = PlaneSampler
# turbsw_.turb5_turbsw.num_points          = 161 45
# turbsw_.turb5_turbsw.origin              = 1188.523196492643 573.0 1.8000000000000114
# turbsw_.turb5_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb5_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb5_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb6_turbsw.type                = PlaneSampler
# turbsw_.turb6_turbsw.num_points          = 161 45
# turbsw_.turb6_turbsw.origin              = 488.5231964926429 1873.0 1.8000000000000114
# turbsw_.turb6_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb6_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb6_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb7_turbsw.type                = PlaneSampler
# turbsw_.turb7_turbsw.num_points          = 161 45
# turbsw_.turb7_turbsw.origin              = 888.5231964926429 1473.0 1.8000000000000114
# turbsw_.turb7_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb7_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb7_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb8_turbsw.type                = PlaneSampler
# turbsw_.turb8_turbsw.num_points          = 161 45
# turbsw_.turb8_turbsw.origin              = 1288.523196492643 1073.0 1.8000000000000114
# turbsw_.turb8_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb8_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb8_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb9_turbsw.type                = PlaneSampler
# turbsw_.turb9_turbsw.num_points          = 161 45
# turbsw_.turb9_turbsw.origin              = 1688.523196492643 673.0 1.8000000000000114
# turbsw_.turb9_turbsw.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb9_turbsw.axis2               = 0.0 0.0 277.2
# turbsw_.turb9_turbsw.normal              = 0.0 0.0 0.0
# turbsw_.turb10_turbsw.type               = PlaneSampler
# turbsw_.turb10_turbsw.num_points         = 161 45
# turbsw_.turb10_turbsw.origin             = 988.5231964926429 1973.0 1.8000000000000114
# turbsw_.turb10_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb10_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb10_turbsw.normal             = 0.0 0.0 0.0
# turbsw_.turb11_turbsw.type               = PlaneSampler
# turbsw_.turb11_turbsw.num_points         = 161 45
# turbsw_.turb11_turbsw.origin             = 1388.523196492643 1573.0 1.8000000000000114
# turbsw_.turb11_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb11_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb11_turbsw.normal             = 0.0 0.0 0.0
# turbsw_.turb12_turbsw.type               = PlaneSampler
# turbsw_.turb12_turbsw.num_points         = 161 45
# turbsw_.turb12_turbsw.origin             = 1788.523196492643 1173.0 1.8000000000000114
# turbsw_.turb12_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb12_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb12_turbsw.normal             = 0.0 0.0 0.0
# turbsw_.turb13_turbsw.type               = PlaneSampler
# turbsw_.turb13_turbsw.num_points         = 161 45
# turbsw_.turb13_turbsw.origin             = 1488.523196492643 2073.0 1.8000000000000114
# turbsw_.turb13_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb13_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb13_turbsw.normal             = 0.0 0.0 0.0
# turbsw_.turb14_turbsw.type               = PlaneSampler
# turbsw_.turb14_turbsw.num_points         = 161 45
# turbsw_.turb14_turbsw.origin             = 1888.523196492643 1673.0 1.8000000000000114
# turbsw_.turb14_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb14_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb14_turbsw.normal             = 0.0 0.0 0.0
# turbsw_.turb15_turbsw.type               = PlaneSampler
# turbsw_.turb15_turbsw.num_points         = 161 45
# turbsw_.turb15_turbsw.origin             = 1988.523196492643 2173.0 1.8000000000000114
# turbsw_.turb15_turbsw.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbsw_.turb15_turbsw.axis2              = 0.0 0.0 277.2
# turbsw_.turb15_turbsw.normal             = 0.0 0.0 0.0
# turbhh_.turb0_turbhh.type                = PlaneSampler
# turbhh_.turb0_turbhh.num_points          = 161 81
# turbhh_.turb0_turbhh.origin              = 314.5231964926429 154.76159824632146 90.0
# turbhh_.turb0_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb0_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb0_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb1_turbhh.type                = PlaneSampler
# turbhh_.turb1_turbhh.num_points          = 161 81
# turbhh_.turb1_turbhh.origin              = 414.5231964926429 654.7615982463215 90.0
# turbhh_.turb1_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb1_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb1_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb2_turbhh.type                = PlaneSampler
# turbhh_.turb2_turbhh.num_points          = 161 81
# turbhh_.turb2_turbhh.origin              = 814.5231964926429 254.76159824632146 90.0
# turbhh_.turb2_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb2_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb2_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb3_turbhh.type                = PlaneSampler
# turbhh_.turb3_turbhh.num_points          = 161 81
# turbhh_.turb3_turbhh.origin              = 514.5231964926429 1154.7615982463215 90.0
# turbhh_.turb3_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb3_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb3_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb4_turbhh.type                = PlaneSampler
# turbhh_.turb4_turbhh.num_points          = 161 81
# turbhh_.turb4_turbhh.origin              = 914.5231964926429 754.7615982463215 90.0
# turbhh_.turb4_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb4_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb4_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb5_turbhh.type                = PlaneSampler
# turbhh_.turb5_turbhh.num_points          = 161 81
# turbhh_.turb5_turbhh.origin              = 1314.523196492643 354.76159824632146 90.0
# turbhh_.turb5_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb5_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb5_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb6_turbhh.type                = PlaneSampler
# turbhh_.turb6_turbhh.num_points          = 161 81
# turbhh_.turb6_turbhh.origin              = 614.5231964926429 1654.7615982463215 90.0
# turbhh_.turb6_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb6_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb6_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb7_turbhh.type                = PlaneSampler
# turbhh_.turb7_turbhh.num_points          = 161 81
# turbhh_.turb7_turbhh.origin              = 1014.5231964926429 1254.7615982463215 90.0
# turbhh_.turb7_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb7_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb7_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb8_turbhh.type                = PlaneSampler
# turbhh_.turb8_turbhh.num_points          = 161 81
# turbhh_.turb8_turbhh.origin              = 1414.523196492643 854.7615982463215 90.0
# turbhh_.turb8_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb8_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb8_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb9_turbhh.type                = PlaneSampler
# turbhh_.turb9_turbhh.num_points          = 161 81
# turbhh_.turb9_turbhh.origin              = 1814.523196492643 454.76159824632146 90.0
# turbhh_.turb9_turbhh.axis1               = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb9_turbhh.axis2               = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb9_turbhh.normal              = 0.0 0.0 0.0
# turbhh_.turb10_turbhh.type               = PlaneSampler
# turbhh_.turb10_turbhh.num_points         = 161 81
# turbhh_.turb10_turbhh.origin             = 1114.523196492643 1754.7615982463215 90.0
# turbhh_.turb10_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb10_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb10_turbhh.normal             = 0.0 0.0 0.0
# turbhh_.turb11_turbhh.type               = PlaneSampler
# turbhh_.turb11_turbhh.num_points         = 161 81
# turbhh_.turb11_turbhh.origin             = 1514.523196492643 1354.7615982463215 90.0
# turbhh_.turb11_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb11_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb11_turbhh.normal             = 0.0 0.0 0.0
# turbhh_.turb12_turbhh.type               = PlaneSampler
# turbhh_.turb12_turbhh.num_points         = 161 81
# turbhh_.turb12_turbhh.origin             = 1914.523196492643 954.7615982463215 90.0
# turbhh_.turb12_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb12_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb12_turbhh.normal             = 0.0 0.0 0.0
# turbhh_.turb13_turbhh.type               = PlaneSampler
# turbhh_.turb13_turbhh.num_points         = 161 81
# turbhh_.turb13_turbhh.origin             = 1614.523196492643 1854.7615982463215 90.0
# turbhh_.turb13_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb13_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb13_turbhh.normal             = 0.0 0.0 0.0
# turbhh_.turb14_turbhh.type               = PlaneSampler
# turbhh_.turb14_turbhh.num_points         = 161 81
# turbhh_.turb14_turbhh.origin             = 2014.523196492643 1454.7615982463215 90.0
# turbhh_.turb14_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb14_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb14_turbhh.normal             = 0.0 0.0 0.0
# turbhh_.turb15_turbhh.type               = PlaneSampler
# turbhh_.turb15_turbhh.num_points         = 161 81
# turbhh_.turb15_turbhh.origin             = 2114.523196492643 1954.7615982463215 90.0
# turbhh_.turb15_turbhh.axis1              = 872.9536070147142 503.99999999999994 0.0
# turbhh_.turb15_turbhh.axis2              = -251.99999999999997 436.4768035073571 -0.0
# turbhh_.turb15_turbhh.normal             = 0.0 0.0 0.0
# turbdomain_.Farm_turbdomain.type         = PlaneSampler
# turbdomain_.Farm_turbdomain.num_points   = 321 321
# turbdomain_.Farm_turbdomain.origin       = 0.0 0.0 90.0
# turbdomain_.Farm_turbdomain.axis1        = 5120.0 0.0 0.0
# turbdomain_.Farm_turbdomain.axis2        = 0.0 5120.0 0.0
# turbdomain_.Farm_turbdomain.normal       = 0.0 0.0 1.0
# turbdomain_.Farm_turbdomain.offsets      = 0.0 126.0
#
# #---- extra params ----
# time.plot_start                          = 30000
# BoussinesqBuoyancy.read_temperature_profile = true
# BoussinesqBuoyancy.tprofile_filename     = /lustre/orion/proj-shared/cfd162/shared/avg_theta.dat
# CoriolisForcing.turn_off_vertical_force  = True
# ABL.inflow_outflow_mode                  = true
# ABL.wf_velocity                          = 6.093275678667113 3.659473797517521
# ABL.wf_vmag                              = 7.12794309269604
# ABL.wf_theta                             = 300.2026467204779
# ABL.enable_hybrid_rl_mode                = true
# amr.max_grid_size                        = 128
# amr.blocking_factor                      = 32
# nodal_proj.max_coarsening_level          = 0
# nodal_proj.num_pre_smooth                = 10
# nodal_proj.num_post_smooth               = 10
# nodal_proj.bottom_rtol                   = 1.0e-9
# nodal_proj.bottom_atol                   = 1.0e-12
# mac_proj.verbose                         = 0
# mac_proj.max_coarsening_level            = 0
# mac_proj.do_nsolve                       = true
# mac_proj.bottom_verbose                  = 0
# mac_proj.bottom_rtol                     = 1.0e-11
# mac_proj.bottom_atol                     = 1.0e-12
# mac_proj.num_pre_smooth                  = 10
# mac_proj.num_post_smooth                 = 10
# diffusion.verbose                        = 0
# diffusion.do_agglomeration               = false
# diffusion.do_nsolve                      = true
# velocity_diffusion.verbose               = 0
# velocity_diffusion.use_tensor_operator   = false
# velocity_diffusion.use_segregated_operator = true
# velocity_diffusion.do_nsolve             = true
# temperature_diffusion.verbose            = 0
# temperature_diffusion.do_nsolve          = true
# amrex.abort_on_out_of_gpu_memory         = 1
# amrex.the_arena_is_managed               = 0
# amrex.hypre_spgemm_use_vendor            = 1
# amrex.hypre_spmv_use_vendor              = 0
# amrex.hypre_sptrans_use_vendor           = 0
# amrex.hypre_umpire_device_pool_mbs       = 4096
# hypre.bamg_verbose                       = 0
# hypre.verbose                            = 0
# hypre.recompute_preconditioner           = 0
# hypre.hypre_solver                       = GMRES
# hypre.hypre_preconditioner               = BoomerAMG
# hypre.num_krylov                         = 40
# hypre.max_iterations                     = 40
# hypre.rtol                               = 1.e-5
# hypre.atol                               = 1.e-8
# hypre.bamg_coarsen_type                  = 8
# hypre.bamg_interp_type                   = 6
# hypre.bamg_relax_type                    = 11
# hypre.bamg_num_sweeps                    = 2
# hypre.bamg_cycle_type                    = 1
# hypre.bamg_relax_order                   = 0
# hypre.bamg_trunc_factor                  = 0.45
# hypre.bamg_strong_threshold              = 0.3
# hypre.bamg_min_coarse_size               = 1
# hypre.bamg_max_coarse_size               = 100
# hypre.bamg_agg_num_levels                = 0
# hypre.bamg_agg_interp_type               = 7
# hypre.bamg_agg_pmax_elmts                = 3
# hypre.bamg_pmax_elmts                    = 3
# hypre.bamg_keep_transpose                = 1
# hypre.write_matrix_files                 = 0
# hypre.bamg_smooth_type                   = 5
# hypre.bamg_smooth_num_sweeps             = 1
# hypre.bamg_smooth_num_levels             = 0
# hypre.bamg_ilu_type                      = 0
# hypre.bamg_ilu_level                     = 0
# hypre.bamg_ilu_max_iter                  = 1
# hypre.bamg_ilu_reordering_type           = 0
# hypre.bamg_ilu_tri_solve                 = 0
# hypre.bamg_ilu_lower_jacobi_iters        = 3
# hypre.bamg_ilu_upper_jacobi_iters        = 3
# #== END AMR-WIND INPUT ==
